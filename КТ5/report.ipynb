# %% [markdown]
# # Report: KT05 — Kubernetes: Подготовительные шаги

# %% [markdown]
# ## Описание
# Кратко опишите задачу и ожидаемый результат.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print('Импорт библиотек успешно')

# %% [markdown]
# ## Данные
# Опишите источник данных и шаги получения/загрузки.

# %%
# Пример заготовки
# df = pd.read_csv('data/processed/dataset.csv')
# df.head()

# %% [markdown]
# ## Визуализация / Результаты

# %%
x = list(range(10))
y = [i**2 for i in x]
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.title('Демо-график')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## Выводы
# Кратко сформулируйте выводы и дальнейшие шаги.
